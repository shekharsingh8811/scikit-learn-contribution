# %%
## --------------------------------------------------------------------
## TO CREATE NEW ENV using the TEST PYPI 
## compiling from source : https://test.pypi.org/project/scikit-learn-3way-split/
## 
## The dependencies are not picked up automatically for some reason and need to be installed manually.
## --------------------------------------------------------------------
## Create the environment and activate it
## 
## pip install numpy>=1.14.0
## pip install scipy>=1.1.0
## pip install joblib>=0.11
## pip install threadpoolctl>=2.0.0
##
## pip install -i https://test.pypi.org/simple/ scikit-learn-3way-split
## 
## Note: pandas is only required for this particular test script
## pip install pandas
## pip install jupyter notebook
##
## --------------------------------------------------------------------
##
##
## --------------------------------------------------------------------
## TO CREATE NEW ENV using the PYPI 
## compiling from source : https://pypi.org/project/scikit-learn-3way-split/
## 
## Here the dependencies are picked up automatically.
## --------------------------------------------------------------------
## Create the environment and activate it
##
## pip install scikit-learn-3way-split
## 
## Note: pandas is only required for this particular test script
## pip install pandas
## pip install jupyter notebook
##
## --------------------------------------------------------------------

# %% [markdown]
# ## This is our own test script where each possible use case is part of a tuple.
# ## They are executed one at a time using the exec statement.
# ## --------------------------
# ## NOTE: Exception handling is only to prevent script from breaking for a use case that should fail; and thus the new use case should be picked up and continue executing.
# ## Verify the error message thrown for the use case that should fail.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_val_split

# %%
data = pd.read_csv("Test_Data.csv")

# %%
data.shape
# Out:
# (100, 17)

# %%
#Slicing of data to devide it into target and feature set
X=data.drop(columns=['Class'])
y=data['Class'].to_frame()

# %%
X.shape
# Out:
# (100, 16)

# %%
y.shape
# Out:
# (100, 1)

# %% [markdown]
# ## Test all combinations:
# ### with the new parameter and we expect 3 (train, test, validation) outputs for each input array
# ### without specifying new parameter, we expect 2 (train, test) outputs for each input array  - backward compatible with/ without   SHUFFLE, STRATIFY

# %%
##############################################################################

# %% [markdown]
# ## Testing the old function train_test_split()

# %%
commandTuple_OLD_Function = (
    "X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=20, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=100, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, train_size=20, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=80, train_size=30, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=20, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, train_size=20, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=1.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.2, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, train_size=0.3, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.2, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.4, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.2, stratify=y, shuffle=False, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.2, shuffle=False, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=20, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, train_size=20, val_size=0, random_state=42)", 
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=80, train_size=30, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=20, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, train_size=20, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, train_size=0.3, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, val_size=80, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=70, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=90, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=90, val_size=15, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=20, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=90, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=90, val_size=15, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=70, train_size=20, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=70, train_size=2, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=70, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=20, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=70, train_size=20, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=70, train_size=2, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, val_size=0.9, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=0.2, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=0.2, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, train_size=0.2, val_size=0.02, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.02, train_size=0.2, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.2, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, stratify=y, shuffle=False, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, shuffle=False, random_state=42)"
)

useCaseNo = 0

for eachCmd in commandTuple_OLD_Function:
    try:
        #run_usecase(eachCmd)
        useCaseNo += 1
        print(f"\n\n--- Use case {useCaseNo} ---")
        print(f"executing command statement =\n{eachCmd}")
        
        X_train, X_test, X_val, y_train, y_test, y_val = [None]*6
        exec(eachCmd)
        
        if X_val is None: # trying an old functionality with only train + test subset return
            print(f"\nOutput =\nX_train=\n{X_train.shape}\nX_test=\n{X_test.shape}\n\ny_train=\n{y_train.shape}\ny_test=\n{y_test.shape}\n\n")
        else: # trying a new functionality with train + test + validation subset return
            print(f"\nOutput =\nX_train=\n{X_train.shape}\nX_test=\n{X_test.shape}\nX_val=\n{X_val.shape}\n\ny_train=\n{y_train.shape}\ny_test=\n{y_test.shape}\ny_val=\n{y_val.shape}\n\n")
    
    ## the exception handling is only to prevent script from breaking with a use case that should fail.
    ##     and thus the new use case should be picked up and continue executing
    except Exception as e:
        print(f"\n{e}\n")
        print(f"\nRECEIVED ERROR - CHECK THE ABOVE MESSAGE --- MOVING TO NEXT USE CASE\n")

print(f"\n\nDone\n\n")
# Out:
# --- Use case 1 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#
# Output =
# X_train=
# (75, 16)
# X_test=
# (25, 16)
#
# y_train=
# (75, 1)
# y_test=
# (25, 1)
#
#
#
#
# --- Use case 2 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=70, random_state=42)
#
# Output =
# X_train=
# (30, 16)
# X_test=
# (70, 16)
#
# y_train=
# (30, 1)
# y_test=
# (70, 1)
#
#
#
#
# --- Use case 3 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, random_state=42)
#
# test_size=100 should be either positive and smaller than the number of samples 100 or a float in the (0, 1) range
#
#
# RECEIVED ERROR - CHECK THE ABOVE MESSAGE --- MOVING TO NEXT USE CASE
#
#
#
# --- Use case 4 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=20, random_state=42)
#
# Output =
# ...

# %%
##############################################################################

# %% [markdown]
# ## Testing the NEW function train_test_val_split()

# %%
commandTuple_NEW_Function = (
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=100, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=20, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=100, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, train_size=20, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=80, train_size=30, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=20, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, train_size=20, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=1.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=0.2, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=1.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.2, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.8, train_size=0.3, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=0.2, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.2, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.4, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.2, stratify=y, shuffle=False, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.2, shuffle=False, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=20, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, train_size=20, val_size=0, random_state=42)", 
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=80, train_size=30, val_size=0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=20, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, train_size=20, val_size=0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=0.7, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.8, train_size=0.3, val_size=0.0, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=0.2, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.0, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, val_size=80, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=70, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=90, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=90, val_size=15, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=20, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=90, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=90, val_size=15, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=70, train_size=20, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=70, train_size=2, val_size=10, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=70, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=20, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=70, train_size=20, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=70, train_size=2, val_size=10, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, val_size=0.9, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=0.2, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=0.2, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, train_size=0.2, val_size=0.02, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.02, train_size=0.2, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.2, stratify=y, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, stratify=y, shuffle=False, random_state=42)",
    "X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, y, test_size=0.7, train_size=0.2, val_size=0.1, shuffle=False, random_state=42)"
)

useCaseNo = 0

for eachCmd in commandTuple_NEW_Function:
    try:
        #run_usecase(eachCmd)
        useCaseNo += 1
        print(f"\n\n--- Use case {useCaseNo} ---")
        print(f"executing command statement =\n{eachCmd}")
        
        X_train, X_test, X_val, y_train, y_test, y_val = [None]*6
        exec(eachCmd)
        
        if X_val is None: # trying an old functionality with only train + test subset return
            print(f"\nOutput =\nX_train=\n{X_train.shape}\nX_test=\n{X_test.shape}\n\ny_train=\n{y_train.shape}\ny_test=\n{y_test.shape}\n\n")
        else: # trying a new functionality with train + test + validation subset return
            print(f"\nOutput =\nX_train=\n{X_train.shape}\nX_test=\n{X_test.shape}\nX_val=\n{X_val.shape}\n\ny_train=\n{y_train.shape}\ny_test=\n{y_test.shape}\ny_val=\n{y_val.shape}\n\n")
    
    ## the exception handling is only to prevent script from breaking with a use case that should fail.
    ##     and thus the new use case should be picked up and continue executing
    except Exception as e:
        print(f"\n{e}\n")
        print(f"\nRECEIVED ERROR - CHECK THE ABOVE MESSAGE --- MOVING TO NEXT USE CASE\n")

print(f"\n\nDone\n\n")
# Out:
# --- Use case 1 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_val_split(X, y, random_state=42)
#
# Output =
# X_train=
# (75, 16)
# X_test=
# (25, 16)
#
# y_train=
# (75, 1)
# y_test=
# (25, 1)
#
#
#
#
# --- Use case 2 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=70, random_state=42)
#
# Output =
# X_train=
# (30, 16)
# X_test=
# (70, 16)
#
# y_train=
# (30, 1)
# y_test=
# (70, 1)
#
#
#
#
# --- Use case 3 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_val_split(X, y, test_size=100, random_state=42)
#
# test_size=100 should be either positive and smaller than the number of samples 100 or a float in the (0, 1) range
#
#
# RECEIVED ERROR - CHECK THE ABOVE MESSAGE --- MOVING TO NEXT USE CASE
#
#
#
# --- Use case 4 ---
# executing command statement =
# X_train, X_test, y_train, y_test = train_test_val_split(X, y, train_size=20, random_state=42)
#
# ...

# %%
##############################################################################
